# %% [markdown]
# <a href="https://colab.research.google.com/github/Sergiodcdn/Geoprocessamento/blob/main/Geopr_aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geobr -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 928.1/928.1 kB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 60.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 74.3 MB/s eta 0:00:00

# %%
# !pip install rtree -q
# para indexação espacial
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.5 MB/s eta 0:00:00

# %%
# !pip install geopandas==0.12.0 -q
# cada versão tem um especificidade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# geobr 0.2.0 requires geopandas<0.8.0,>=0.7.0, but you have geopandas 0.12.0 which is incompatible.

# %%
import geobr

# %%
geobr.list_geobr()
# Out:
# Function: read_country
# Geographies available: Country
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_region
# Geographies available: Region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_state
# Geographies available: States
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_meso_region
# Geographies available: Meso region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_micro_region
# Geographies available: Micro region
# ...

# %%
censo_sp_2010 = geobr.read_census_tract(code_tract="SP", year=2010)

# %%
censo_sp_2010.head(5)
# Out:
#         code_tract    zone  code_muni     name_muni name_neighborhood  \
# 0  354100005000009  URBANO  3541000.0  Praia Grande         Boqueirão
# 1  354100005000004  URBANO  3541000.0  Praia Grande         Boqueirão
# 2  354100005000002  URBANO  3541000.0  Praia Grande         Boqueirão
# 3  354100005000001  URBANO  3541000.0  Praia Grande         Boqueirão
# 4  354100005000003  URBANO  3541000.0  Praia Grande         Boqueirão
#
#    code_neighborhood  code_subdistrict  name_subdistrict  code_district  \
# 0       3.541000e+11      3.541000e+10               NaN    354100005.0
# 1       3.541000e+11      3.541000e+10               NaN    354100005.0
# 2       3.541000e+11      3.541000e+10               NaN    354100005.0
# 3       3.541000e+11      3.541000e+10               NaN    354100005.0
# 4       3.541000e+11      3.541000e+10               NaN    354100005.0
#
#   name_district  code_state                                           geometry
# ...

# %%
# mostra n° linhas e colunas no dataframe:
censo_sp_2010.shape
# Out:
# (68296, 12)

# %%
import geopandas as gpd

# %%
# censo_sp_2010 = gpd.read_file("code_track")

# %%
import pandas as pd

# %%
censo_is_2010 = censo_sp_2010[censo_sp_2010['name_district']=="Ilha Solteira"]

# %%
censo_is_2010.head()
# Out:
#             code_tract    zone  code_muni      name_muni name_neighborhood  \
# 18635  352044205000001  URBANO  3520442.0  Ilha Solteira               NaN
# 18636  352044205000002  URBANO  3520442.0  Ilha Solteira               NaN
# 18637  352044205000003  URBANO  3520442.0  Ilha Solteira               NaN
# 18638  352044205000004  URBANO  3520442.0  Ilha Solteira               NaN
# 18639  352044205000005  URBANO  3520442.0  Ilha Solteira               NaN
#
#        code_neighborhood  code_subdistrict  name_subdistrict  code_district  \
# 18635                NaN      3.520442e+10               NaN    352044205.0
# 18636                NaN      3.520442e+10               NaN    352044205.0
# 18637                NaN      3.520442e+10               NaN    352044205.0
# 18638                NaN      3.520442e+10               NaN    352044205.0
# 18639                NaN      3.520442e+10               NaN    352044205.0
#
#        name_district  code_state  \
# ...

# %%
censo_is_2010.plot()
# Out:
# <Axes: >

# %%
saude = geobr.read_health_facilities()

# %%
# !pip install contextily -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 74.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 6.6 MB/s eta 0:00:00

# %%
import contextily as cx
import matplotlib.pyplot as plt

fig,eixo = plt.subplots(figsize=(10,10))

censo_is_2010.plot(ax=eixo, zorder=1)

cx.add_basemap(ax=eixo, crs=censo_is_2010.crs)
